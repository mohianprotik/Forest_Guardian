# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# !pip install librosa
# Out:
# Requirement already satisfied: librosa in c:\users\mohia\anaconda3\lib\site-packages (0.8.1)
# Requirement already satisfied: audioread>=2.0.0 in c:\users\mohia\anaconda3\lib\site-packages (from librosa) (2.1.9)
# Requirement already satisfied: soundfile>=0.10.2 in c:\users\mohia\anaconda3\lib\site-packages (from librosa) (0.10.3.post1)
# Requirement already satisfied: joblib>=0.14 in c:\users\mohia\anaconda3\lib\site-packages (from librosa) (0.17.0)
# Requirement already satisfied: decorator>=3.0.0 in c:\users\mohia\anaconda3\lib\site-packages (from librosa) (4.4.2)
# Requirement already satisfied: numpy>=1.15.0 in c:\users\mohia\anaconda3\lib\site-packages (from librosa) (1.19.2)
# Requirement already satisfied: scikit-learn!=0.19.0,>=0.14.0 in c:\users\mohia\anaconda3\lib\site-packages (from librosa) (0.23.2)
# Requirement already satisfied: packaging>=20.0 in c:\users\mohia\anaconda3\lib\site-packages (from librosa) (20.4)
# Requirement already satisfied: resampy>=0.2.2 in c:\users\mohia\anaconda3\lib\site-packages (from librosa) (0.2.2)
# Requirement already satisfied: pooch>=1.0 in c:\users\mohia\anaconda3\lib\site-packages (from librosa) (1.4.0)
# Requirement already satisfied: scipy>=1.0.0 in c:\users\mohia\anaconda3\lib\site-packages (from librosa) (1.5.2)
# Requirement already satisfied: numba>=0.43.0 in c:\users\mohia\anaconda3\lib\site-packages (from librosa) (0.51.2)
# Requirement already satisfied: cffi>=1.0 in c:\users\mohia\anaconda3\lib\site-packages (from soundfile>=0.10.2->librosa) (1.14.3)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\mohia\anaconda3\lib\site-packages (from scikit-learn!=0.19.0,>=0.14.0->librosa) (2.1.0)
# Requirement already satisfied: six in c:\users\mohia\anaconda3\lib\site-packages (from packaging>=20.0->librosa) (1.15.0)
# Requirement already satisfied: pyparsing>=2.0.2 in c:\users\mohia\anaconda3\lib\site-packages (from packaging>=20.0->librosa) (2.4.7)
# Requirement already satisfied: appdirs in c:\users\mohia\anaconda3\lib\site-packages (from pooch>=1.0->librosa) (1.4.4)
# Requirement already satisfied: requests in c:\users\mohia\anaconda3\lib\site-packages (from pooch>=1.0->librosa) (2.24.0)
# Requirement already satisfied: llvmlite<0.35,>=0.34.0.dev0 in c:\users\mohia\anaconda3\lib\site-packages (from numba>=0.43.0->librosa) (0.34.0)
# Requirement already satisfied: setuptools in c:\users\mohia\anaconda3\lib\site-packages (from numba>=0.43.0->librosa) (50.3.1.post20201107)
# Requirement already satisfied: pycparser in c:\users\mohia\anaconda3\lib\site-packages (from cffi>=1.0->soundfile>=0.10.2->librosa) (2.20)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\mohia\anaconda3\lib\site-packages (from requests->pooch>=1.0->librosa) (2020.6.20)
# Requirement already satisfied: chardet<4,>=3.0.2 in c:\users\mohia\anaconda3\lib\site-packages (from requests->pooch>=1.0->librosa) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\mohia\anaconda3\lib\site-packages (from requests->pooch>=1.0->librosa) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\users\mohia\anaconda3\lib\site-packages (from requests->pooch>=1.0->librosa) (1.25.11)

# %%
import IPython.display as ipd
import librosa
import librosa.display

# %%
filename = 'dataset1/fold1/7061-6-0-0.wav'

# %%
plt.figure(figsize = (14,5))
data,sample_rate=librosa.load(filename)
librosa.display.waveplot(data,sr = sample_rate)
ipd.Audio(filename)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
sample_rate
# Out:
# 22050

# %%
from scipy.io import wavfile as wav
wave_sample_rate, wave_audio = wav.read(filename)

# %%
wave_sample_rate
# Out:
# 44100

# %%
wave_audio
# Out:
# array([[0, 0],
#        [0, 0],
#        [0, 0],
#        ...,
#        [1, 0],
#        [1, 1],
#        [0, 0]], dtype=int16)

# %%
plt.plot(wave_audio)
# Out:
# [<matplotlib.lines.Line2D at 0x229edb52970>,
#  <matplotlib.lines.Line2D at 0x229edb528b0>]

# %%
data
# Out:
# array([0.0000000e+00, 0.0000000e+00, 0.0000000e+00, ..., 1.0231203e-05,
#        2.3116412e-05, 0.0000000e+00], dtype=float32)

# %%
import pandas as pd
audio_dataset_path = 'dataset1'
metadata = pd.read_csv('dataset1/UrbanSound8k.csv')
metadata.head()
# Out:
#       slice_file_name    fsID  start        end  salience  fold  classID  \
# 0    100032-3-0-0.wav  100032    0.0   0.317551         1     5        3
# 1  100263-2-0-117.wav  100263   58.5  62.500000         1     5        2
# 2  100263-2-0-121.wav  100263   60.5  64.500000         1     5        2
# 3  100263-2-0-126.wav  100263   63.0  67.000000         1     5        2
# 4  100263-2-0-137.wav  100263   68.5  72.500000         1     5        2
#
#               class
# 0          dog_bark
# 1  children_playing
# 2  children_playing
# 3  children_playing
# 4  children_playing

# %%
metadata['class'].value_counts()
# Out:
# children_playing    1000
# drilling            1000
# jackhammer          1000
# dog_bark            1000
# air_conditioner     1000
# street_music        1000
# engine_idling       1000
# siren                929
# car_horn             429
# gun_shot             374
# Name: class, dtype: int64

# %%
metadata['class'].unique()
# Out:
# array(['dog_bark', 'children_playing', 'car_horn', 'air_conditioner',
#        'street_music', 'gun_shot', 'siren', 'engine_idling', 'jackhammer',
#        'drilling'], dtype=object)

# %%
#Extract Features

# %%
mfccs = librosa.feature.mfcc(y = data, sr = sample_rate,n_mfcc=40)
print(mfccs.shape)
# Out:
# (40, 97)

# %%
mfccs
# Out:
# array([[-9.3800201e+01,  7.4964676e+00,  1.5476104e+01, ...,
#         -5.6935333e+02, -5.9172742e+02, -6.1055634e+02],
#        [ 3.0774033e+01,  2.3719746e+01,  1.1416364e+01, ...,
#          4.3051193e+01,  2.5888165e+01,  1.2927567e+01],
#        [-3.2866507e+00, -1.2030355e+01, -1.5005075e+01, ...,
#         -1.1103721e+01, -7.5504951e+00,  2.2212185e-01],
#        ...,
#        [ 6.4266539e-01, -3.2603269e+00, -4.7559185e+00, ...,
#          2.4095769e+00,  3.1699095e+00, -1.5433559e-01],
#        [-1.0001830e+01, -9.3599148e+00, -6.4467368e+00, ...,
#         -5.0200760e-02,  7.2894061e-01, -8.3965683e-01],
#        [ 1.9421942e+00,  2.0736120e+00,  3.0683601e+00, ...,
#         -2.0609195e+00, -2.2312031e+00, -1.7239641e+00]], dtype=float32)

# %%
def features_extractor(file):
    audio,sample_rate = librosa.load(file_name,res_type = 'Kaiser_fast')
    mfccs_features = librosa.feature.mfcc(y = audio, sr = sample_rate,n_mfcc =40)
    mfccs_scaled_features = np.mean(mfccs_features.T , axis = 0)
    
    return mfccs_scaled_features

# %%
import numpy as np
import os
from tqdm import tqdm
##iterate through every audio file and extract feaures
##using MEL-frequency cepstral coefficients

extracted_features=[]
for index_num, row in tqdm(metadata.iterrows()):
    file_name = os.path.join(os.path.abspath(audio_dataset_path),'fold'+str(row["fold"])+'/',str(row["slice_file_name"]))
    final_class_labels = row['class']
    data = features_extractor(file_name)
    extracted_features.append([data,final_class_labels])
# Out:
# 3555it [03:04, 19.28it/s]C:\Users\mohia\anaconda3\lib\site-packages\librosa\core\spectrum.py:222: UserWarning: n_fft=2048 is too small for input signal of length=1323
#   warnings.warn(
# 8324it [07:00, 25.05it/s]C:\Users\mohia\anaconda3\lib\site-packages\librosa\core\spectrum.py:222: UserWarning: n_fft=2048 is too small for input signal of length=1103
#   warnings.warn(
# C:\Users\mohia\anaconda3\lib\site-packages\librosa\core\spectrum.py:222: UserWarning: n_fft=2048 is too small for input signal of length=1523
#   warnings.warn(
# 8732it [07:19, 19.88it/s]

# %%
extracted_features_df = pd.DataFrame(extracted_features,columns=['feature','class'])
extracted_features_df.head()
# Out:
#                                              feature             class
# 0  [-215.79301, 71.66612, -131.81377, -52.091328,...          dog_bark
# 1  [-424.68683, 110.56227, -54.14824, 62.01073, -...  children_playing
# 2  [-459.56467, 122.80034, -47.92471, 53.265694, ...  children_playing
# 3  [-414.55377, 102.896904, -36.664948, 54.18041,...  children_playing
# 4  [-447.397, 115.0954, -53.809113, 61.608585, 1....  children_playing

# %%
X = np.array(extracted_features_df['feature'].tolist())
y = np.array(extracted_features_df['class'].tolist())

# %%
X.shape
# Out:
# (8732, 40)

# %%
## 
y = np.array(pd.get_dummies(y))

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state =0)

# %%
X_train.shape
# Out:
# (6985, 40)

# %% [markdown]
# # Model Creation

# %%
# !pip install tensorflow
# Out:
# ERROR: Exception:
# Traceback (most recent call last):
#   File "C:\Users\mohia\anaconda3\lib\site-packages\pip\_vendor\urllib3\response.py", line 437, in _error_catcher
#     yield
#   File "C:\Users\mohia\anaconda3\lib\site-packages\pip\_vendor\urllib3\response.py", line 519, in read
#     data = self._fp.read(amt) if not fp_closed else b""
#   File "C:\Users\mohia\anaconda3\lib\site-packages\pip\_vendor\cachecontrol\filewrapper.py", line 62, in read
#     data = self.__fp.read(amt)
#   File "C:\Users\mohia\anaconda3\lib\http\client.py", line 458, in read
#     n = self.readinto(b)
#   File "C:\Users\mohia\anaconda3\lib\http\client.py", line 502, in readinto
#     n = self.fp.readinto(b)
#   File "C:\Users\mohia\anaconda3\lib\socket.py", line 669, in readinto
#     return self._sock.recv_into(b)
#   File "C:\Users\mohia\anaconda3\lib\ssl.py", line 1241, in recv_into
#     return self.read(nbytes, buffer)
#   File "C:\Users\mohia\anaconda3\lib\ssl.py", line 1099, in read
#     return self._sslobj.read(len, buffer)
# socket.timeout: The read operation timed out
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\mohia\anaconda3\lib\site-packages\pip\_internal\cli\base_command.py", line 228, in _main
#     status = self.run(options, args)
#   File "C:\Users\mohia\anaconda3\lib\site-packages\pip\_internal\cli\req_command.py", line 182, in wrapper
#     return func(self, options, args)
#   File "C:\Users\mohia\anaconda3\lib\site-packages\pip\_internal\commands\install.py", line 323, in run
#     requirement_set = resolver.resolve(
#   File "C:\Users\mohia\anaconda3\lib\site-packages\pip\_internal\resolution\legacy\resolver.py", line 183, in resolve
#     discovered_reqs.extend(self._resolve_one(requirement_set, req))
#   File "C:\Users\mohia\anaconda3\lib\site-packages\pip\_internal\resolution\legacy\resolver.py", line 388, in _resolve_one
#     abstract_dist = self._get_abstract_dist_for(req_to_install)
#   File "C:\Users\mohia\anaconda3\lib\site-packages\pip\_internal\resolution\legacy\resolver.py", line 340, in _get_abstract_dist_for
#     abstract_dist = self.preparer.prepare_linked_requirement(req)
#   File "C:\Users\mohia\anaconda3\lib\site-packages\pip\_internal\operations\prepare.py", line 467, in prepare_linked_requirement
#     local_file = unpack_url(
#   File "C:\Users\mohia\anaconda3\lib\site-packages\pip\_internal\operations\prepare.py", line 255, in unpack_url
#     file = get_http_url(
#   File "C:\Users\mohia\anaconda3\lib\site-packages\pip\_internal\operations\prepare.py", line 129, in get_http_url
#     from_path, content_type = _download_http_url(
#   File "C:\Users\mohia\anaconda3\lib\site-packages\pip\_internal\operations\prepare.py", line 282, in _download_http_url
#     for chunk in download.chunks:
#   File "C:\Users\mohia\anaconda3\lib\site-packages\pip\_internal\cli\progress_bars.py", line 168, in iter
#     for x in it:
#   File "C:\Users\mohia\anaconda3\lib\site-packages\pip\_internal\network\utils.py", line 64, in response_chunks
#     for chunk in response.raw.stream(
#   File "C:\Users\mohia\anaconda3\lib\site-packages\pip\_vendor\urllib3\response.py", line 576, in stream
#     data = self.read(amt=amt, decode_content=decode_content)
#   File "C:\Users\mohia\anaconda3\lib\site-packages\pip\_vendor\urllib3\response.py", line 541, in read
#     raise IncompleteRead(self._fp_bytes_read, self.length_remaining)
#   File "C:\Users\mohia\anaconda3\lib\contextlib.py", line 131, in __exit__
#     self.gen.throw(type, value, traceback)
#   File "C:\Users\mohia\anaconda3\lib\site-packages\pip\_vendor\urllib3\response.py", line 442, in _error_catcher
#     raise ReadTimeoutError(self._pool, None, "Read timed out.")
# pip._vendor.urllib3.exceptions.ReadTimeoutError: HTTPSConnectionPool(host='files.pythonhosted.org', port=443): Read timed out.
# Collecting tensorflow
#   Downloading tensorflow-2.5.0-cp38-cp38-win_amd64.whl (422.6 MB)
# Collecting tensorflow
#   Downloading tensorflow-2.5.0-cp38-cp38-win_amd64.whl (422.6 MB)
# Collecting h5py~=3.1.0
#   Downloading h5py-3.1.0-cp38-cp38-win_amd64.whl (2.7 MB)
# Collecting keras-nightly~=2.5.0.dev
#   Using cached keras_nightly-2.5.0.dev2021032900-py2.py3-none-any.whl (1.2 MB)
# Collecting tensorflow-estimator<2.6.0,>=2.5.0rc0
#   Using cached tensorflow_estimator-2.5.0-py2.py3-none-any.whl (462 kB)
# Collecting gast==0.4.0
#   Using cached gast-0.4.0-py3-none-any.whl (9.8 kB)
# Collecting google-pasta~=0.2
#   Using cached google_pasta-0.2.0-py3-none-any.whl (57 kB)
# Collecting flatbuffers~=1.12.0
#   Using cached flatbuffers-1.12-py2.py3-none-any.whl (15 kB)
# Collecting termcolor~=1.1.0
#   Using cached termcolor-1.1.0.tar.gz (3.9 kB)
# Collecting grpcio~=1.34.0
#   Downloading grpcio-1.34.1-cp38-cp38-win_amd64.whl (2.9 MB)
# Collecting tensorboard~=2.5
#   Using cached tensorboard-2.5.0-py3-none-any.whl (6.0 MB)
# Requirement already satisfied: typing-extensions~=3.7.4 in c:\users\mohia\anaconda3\lib\site-packages (from tensorflow) (3.7.4.3)
# Collecting absl-py~=0.10
#   Using cached absl_py-0.13.0-py3-none-any.whl (132 kB)
# Requirement already satisfied: wheel~=0.35 in c:\users\mohia\anaconda3\lib\site-packages (from tensorflow) (0.35.1)
# Collecting astunparse~=1.6.3
#   Using cached astunparse-1.6.3-py2.py3-none-any.whl (12 kB)
# Collecting opt-einsum~=3.3.0
#   Using cached opt_einsum-3.3.0-py3-none-any.whl (65 kB)
# Collecting keras-preprocessing~=1.1.2
#   Using cached Keras_Preprocessing-1.1.2-py2.py3-none-any.whl (42 kB)
# Requirement already satisfied: numpy~=1.19.2 in c:\users\mohia\anaconda3\lib\site-packages (from tensorflow) (1.19.2)
# Requirement already satisfied: six~=1.15.0 in c:\users\mohia\anaconda3\lib\site-packages (from tensorflow) (1.15.0)
# Collecting protobuf>=3.9.2
#   Downloading protobuf-3.17.3-cp38-cp38-win_amd64.whl (909 kB)
# Collecting wrapt~=1.12.1
#   Using cached wrapt-1.12.1.tar.gz (27 kB)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\mohia\anaconda3\lib\site-packages (from tensorboard~=2.5->tensorflow) (2.24.0)
# Requirement already satisfied: werkzeug>=0.11.15 in c:\users\mohia\anaconda3\lib\site-packages (from tensorboard~=2.5->tensorflow) (1.0.1)
# Collecting tensorboard-plugin-wit>=1.6.0
#   Using cached tensorboard_plugin_wit-1.8.0-py3-none-any.whl (781 kB)
# Requirement already satisfied: setuptools>=41.0.0 in c:\users\mohia\anaconda3\lib\site-packages (from tensorboard~=2.5->tensorflow) (50.3.1.post20201107)
# Collecting google-auth-oauthlib<0.5,>=0.4.1
#   Using cached google_auth_oauthlib-0.4.4-py2.py3-none-any.whl (18 kB)
# Collecting markdown>=2.6.8
#   Using cached Markdown-3.3.4-py3-none-any.whl (97 kB)
# Collecting google-auth<2,>=1.6.3
#   Downloading google_auth-1.32.1-py2.py3-none-any.whl (147 kB)
# Collecting tensorboard-data-server<0.7.0,>=0.6.0
#   Using cached tensorboard_data_server-0.6.1-py3-none-any.whl (2.4 kB)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\users\mohia\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard~=2.5->tensorflow) (1.25.11)
# Requirement already satisfied: chardet<4,>=3.0.2 in c:\users\mohia\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard~=2.5->tensorflow) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\mohia\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard~=2.5->tensorflow) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\mohia\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard~=2.5->tensorflow) (2020.6.20)
# Collecting requests-oauthlib>=0.7.0
#   Using cached requests_oauthlib-1.3.0-py2.py3-none-any.whl (23 kB)
# Collecting rsa<5,>=3.1.4; python_version >= "3.6"
#   Using cached rsa-4.7.2-py3-none-any.whl (34 kB)
# Collecting pyasn1-modules>=0.2.1
#   Using cached pyasn1_modules-0.2.8-py2.py3-none-any.whl (155 kB)
# Collecting cachetools<5.0,>=2.0.0
#   Using cached cachetools-4.2.2-py3-none-any.whl (11 kB)
# Collecting oauthlib>=3.0.0
#   Using cached oauthlib-3.1.1-py2.py3-none-any.whl (146 kB)
# Collecting pyasn1>=0.1.3
#   Using cached pyasn1-0.4.8-py2.py3-none-any.whl (77 kB)
# Building wheels for collected packages: termcolor, wrapt
#   Building wheel for termcolor (setup.py): started
#   Building wheel for termcolor (setup.py): finished with status 'done'
#   Created wheel for termcolor: filename=termcolor-1.1.0-py3-none-any.whl size=4835 sha256=2716a668b7f37d60f4029582260e232ca353419643e06b555612df8d2041dcac
#   Stored in directory: c:\users\mohia\appdata\local\pip\cache\wheels\a0\16\9c\5473df82468f958445479c59e784896fa24f4a5fc024b0f501
#   Building wheel for wrapt (setup.py): started
#   Building wheel for wrapt (setup.py): finished with status 'done'
#   Created wheel for wrapt: filename=wrapt-1.12.1-py3-none-any.whl size=19558 sha256=23cb13e24f37e53d0f4f777ec004efbce1c9cb99e11f003105a13a2997cb375e
#   Stored in directory: c:\users\mohia\appdata\local\pip\cache\wheels\5f\fd\9e\b6cf5890494cb8ef0b5eaff72e5d55a70fb56316007d6dfe73
# Successfully built termcolor wrapt
# Installing collected packages: h5py, keras-nightly, tensorflow-estimator, gast, google-pasta, flatbuffers, termcolor, grpcio, tensorboard-plugin-wit, oauthlib, requests-oauthlib, pyasn1, rsa, pyasn1-modules, cachetools, google-auth, google-auth-oauthlib, absl-py, protobuf, markdown, tensorboard-data-server, tensorboard, astunparse, opt-einsum, keras-preprocessing, wrapt, tensorflow
#   Attempting uninstall: h5py
#     Found existing installation: h5py 2.10.0
#     Uninstalling h5py-2.10.0:
#       Successfully uninstalled h5py-2.10.0
#   Attempting uninstall: wrapt
#     Found existing installation: wrapt 1.11.2
#     Uninstalling wrapt-1.11.2:
#       Successfully uninstalled wrapt-1.11.2
# Successfully installed absl-py-0.13.0 astunparse-1.6.3 cachetools-4.2.2 flatbuffers-1.12 gast-0.4.0 google-auth-1.32.1 google-auth-oauthlib-0.4.4 google-pasta-0.2.0 grpcio-1.34.1 h5py-3.1.0 keras-nightly-2.5.0.dev2021032900 keras-preprocessing-1.1.2 markdown-3.3.4 oauthlib-3.1.1 opt-einsum-3.3.0 protobuf-3.17.3 pyasn1-0.4.8 pyasn1-modules-0.2.8 requests-oauthlib-1.3.0 rsa-4.7.2 tensorboard-2.5.0 tensorboard-data-server-0.6.1 tensorboard-plugin-wit-1.8.0 tensorflow-2.5.0 tensorflow-estimator-2.5.0 termcolor-1.1.0 wrapt-1.12.1

# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-f83c6d50081b> in <module>
# ----> 1 import tensorflow as tf
#       2 print(tf.__version__)
#
# ModuleNotFoundError: No module named 'tensorflow'

# %%
num_labels = y.shape[1]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-ac4460899757> in <module>
# ----> 1 num_labels = y.shape[1]
#
# NameError: name 'y' is not defined

# %%
Dense()

# %%
model = Sequential()
#First Layer
model.add(Dense(100,input_shape = (40,)))
model.add(Activation('relu'))
model.add(Dropout(0.5))
#Second Layer
model.add(Dense(200))
model.add(Activation('relu'))
model.add(Dropout(0.5))
#third Layer
model.add(Dense(200))
model.add(Activation('relu'))
model.add(Dropout(0.5))
#final layer
model.add(Dense(num_labels))
mode.add(Activation('Softmax'))

# %%
model.summary()

# %%
model.compile(loss= 'categorical_crossentropy',metrics=['accuracy'],optimizer='adam')

# %%
#Training model
